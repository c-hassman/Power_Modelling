# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
os.chdir(r"C:\Users\Colburn_Hassman\Desktop")

# %%
houston = pd.read_pickle("HOUSTON.pkl")
houston['Date'] = pd.to_datetime(houston['Date'])
houston.set_index("Date", inplace = True)

# %%
houston.head()
# Out:
#                           Temp
# Date
# 2002-01-01 00:00:00  37.000000
# 2002-01-01 01:00:00  37.060769
# 2002-01-01 02:00:00  37.241230
# 2002-01-01 03:00:00  37.535898
# 2002-01-01 04:00:00  37.935822

# %%
houston.loc['2006', ['Temp']].plot(figsize = (15,5))
plt.show()

# %%
paso = pd.read_pickle("EL_PASO.pkl")
paso['Date'] = pd.to_datetime(paso['Date'])
paso.set_index("Date", inplace = True)
paso.head()
# Out:
#                           Temp
# Date
# 2002-01-01 00:00:00  32.500000
# 2002-01-01 01:00:00  32.583557
# 2002-01-01 02:00:00  32.831691
# 2002-01-01 03:00:00  33.236860
# 2002-01-01 04:00:00  33.786756

# %%
paso.loc['2011-02',['Temp']].plot(figsize = (15,5))
plt.show()

# %%
paso.loc['2005',['Temp']].plot(figsize = (15, 5))
plt.show()

# %%
paso['Temp'].plot(figsize = (15, 5))
plt.show()

# %%
paso.loc['2002-04-01':'2002-05-01', ['Temp']].plot(figsize=(15,5))
plt.show()

# %%
x = "TYLER.pkl"
data = pd.read_pickle(x)
data['Date'] = pd.to_datetime(data['Date'])
data.set_index("Date", inplace = True)
data['Temp'].plot(figsize=(15,5))
plt.show()
